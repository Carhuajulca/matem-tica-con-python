# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

# %%
# escribe aqui los simbolos
x = symbols('x')

# %%
# ejemplo 001
eq = 3*x - 2
print("x = ", solve(eq,x))
# Out:
# x =  [2/3]

# %%
# ejemplo 002
eq = input('Ingrese su ecuación: 0 = ')
print("x = ", solve(eq,x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Error from parse_expr with transformed code: "Integer (3 )Symbol ('x' )"
#
# The above exception was the direct cause of the following exception:
#
# SyntaxError                               Traceback (most recent call last)
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\core\sympify.py:495, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     494     a = a.replace('\n', '')
# --> 495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\parsing\sympy_parser.py:1087, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1086     local_dict[i] = null
# -> 1087 raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\parsing\sympy_parser.py:1078, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1077 try:
# -> 1078     rv = eval_expr(code, local_dict, global_dict)
#    1079     # restore neutral definitions for names
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\parsing\sympy_parser.py:906, in eval_expr(code, local_dict, global_dict)
#     901 """
#     902 Evaluate Python code generated by ``stringify_expr``.
#     903
#     904 Generally, ``parse_expr`` should be used.
#     905 """
# --> 906 expr = eval(
#     907     code, global_dict, local_dict)  # take local objects in preference
#     908 return expr
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 # ejemplo 002
#       2 eq = input('Ingrese su ecuación: 0 = ')
# ----> 3 print("x = ", solve(eq,x))
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\solvers\solvers.py:874, in solve(f, *symbols, **flags)
#     872 def _sympified_list(w):
#     873     return list(map(sympify, w if iterable(w) else [w]))
# --> 874 f, symbols = (_sympified_list(w) for w in [f, symbols])
#     876 # preprocess symbol(s)
#     877 ###########################################################################
#     879 ordered_symbols = None  # were the symbols in a well defined order?
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\solvers\solvers.py:874, in <genexpr>(.0)
#     872 def _sympified_list(w):
#     873     return list(map(sympify, w if iterable(w) else [w]))
# --> 874 f, symbols = (_sympified_list(w) for w in [f, symbols])
#     876 # preprocess symbol(s)
#     877 ###########################################################################
#     879 ordered_symbols = None  # were the symbols in a well defined order?
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\solvers\solvers.py:873, in solve.<locals>._sympified_list(w)
#     872 def _sympified_list(w):
# --> 873     return list(map(sympify, w if iterable(w) else [w]))
#
# File d:\GESLER\PYTHON\PYTHON11\LEARNIG-PYTHON\lib\site-packages\sympy\core\sympify.py:497, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
# --> 497     raise SympifyError('could not parse %r' % a, exc)
#     499 return expr
#
# SympifyError: Sympify of expression 'could not parse '3x'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)

# %%
# ejmplo 003
eq = 3*x - 2
solution = solve(eq,x)
print("x = ", solution[0])
# Out:
# x =  2/3

# %%
# Cuando la ecuación tiene dos o más soluciones 
# (x-1)*(x+2)*(x-3)
eq = input('Ingrese su ecuación: 0 = ')

solution = solve(eq,x)
for s in solution:
    print("x = ", s)
# Out:
# x =  -2
# x =  1
# x =  3

# %%
# Segunda forma de nombrar variables con sympy
from sympy import *
# Creando variables 
var('x y')

first = 2*x + 10
eql = Eq(first, y)
sol = solve(eql, x)
print("x = ", sol[0])
# Out:
# x =  y/2 - 5

# %%
# Resolver la siguiente ecuación
# 5x+5=3x+7

var('x')
left = 5*x+5
right = 3*x+7
eql = Eq(left, right)
sol = solve(eql, x)
print("x = ", sol[0])
# Out:
# x =  1

# %%
# Sacando Factorial
# Ejemplo 001
# 2x+10y+4
import sympy
from sympy import symbols
from sympy import *

var('x y')

eq = 2*x+10*y+4

sympy.factor(eq)
# Out:
# 2*(x + 5*y + 2)

# %%
# Ejemplo 002
import sympy
from sympy import symbols

var('x y')
eq = x**3-2*x**2 - 5*x+6
sympy.factor(eq)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %%
# convierte la entrada de cadena () incluidas las fracciones) a flotante
def string_frac(in_string):
    if "/" in in_string:
        nd = in_string.split("/")
        n = float(nd[0])
        d = float(nd[1])
        ans = n/d
        return ans
    else:
        ans  = float(in_string)
        return ans
